# %%
import pandas as pd

# %% [markdown]
# #2 main datatypes

# %%
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
#Series : 1-Dimensional

# %%
colors = pd.Series(["Blue","Green","Red"])
colors
# Out:
# 0     Blue
# 1    Green
# 2      Red
# dtype: object

# %%
# Dataframe : 2-Dimensional 
car_data = pd.DataFrame({"Car make": series, "color": colors})
car_data
# Out:
#   Car make  color
# 0      BMW   Blue
# 1   Toyota  Green
# 2    Honda    Red

# %%
#importing a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a DataFrame
car_sales.to_csv("exported-car-sales.csv",index = False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Importing a dataframe from github (Raw Data)
car_sales2 = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv")
car_sales2
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#Attributes (which do not contain parenthesis)
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# describe function works only on numeric cols
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000,1500,112000])
car_prices.mean()
# Out:
# 38833.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Price"].sum()
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc
animals = pd.Series(['cat','dog','bird','panda','snake'],index = [0,3,9,8,3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# loc refers to the index
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
#iloc refers to the position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[6]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        45698
# Doors                    4
# Price            $7,500.00
# Name: 6, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# slice the iloc upto position 3
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-cffc0afb7077> in <module>
# ----> 1 car_sales.Odometer (KM)
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
car_sales["Odometer (KM)"]

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# crossover the 'Make' column with the 'Doors' column
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group by
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Colour"]).mean()
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Blue     44328.333333  3.666667
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000

# %%
# If the below cell doesnt run then run this cell's code first
# The '%' sign indicates something as a magical function
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
# for visualizing Histogram
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].hist()
# Out:
# <AxesSubplot:>

# %%
# The error is due to the non-numeric datatype of Price column
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-89d88ff9f55b> in <module>
#       1 # The error is due to the non-numeric datatype of Price column
# ----> 2 car_sales["Price"].plot()
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
# dtype('O') means Object Datatype
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
# To change the 'Object' datatype to 'int' datatype of 'Price' column with thw help of astype()
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# for removing the extra 2 zeroes added as cents in the 'Price' coloumn above
car_sales["Price"] /=100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Price"].dtype
# Out:
# dtype('float64')

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
# To make all strings lowercase
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# but it doesnt save in the original table
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Assign the values to the dataframe in order to save the column
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
# importing the missing data in seperate dataframe
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# we are going to fill the 'NaN' values in Odometer column with the mean of already existing data using fillna()
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# to actually reflect the changes in the original dataframe, assign the changes done
# car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# (OR)
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# create another dataframe by dropping the missing values
car_sales_missing_dropped = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# dropna() will drop the NaN value rows from the dataframe
car_sales_missing_dropped = car_sales_missing_dropped.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# export dataframe
car_sales_missing_dropped.to_csv("car-sales-extended-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
# column from series
seats_column = pd.Series([5,5,5,5,5])

# new column called Seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
# fill the NaN values in Seats column
car_sales["Seats"].fillna(5,inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
# column from python list
fuel_economy = [7.5,9.2,8.5,6.7,5.0,6.5,5.3,2.3,3.5,5.2]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             8.5
# 3     bmw  Black          11179      5  22000.0    5.0             6.7
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.5
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 8  toyota  White          60000      4   6250.0    5.0             3.5
# 9  nissan  White          31600      4   9700.0    5.0             5.2

# %%
# If using python lists, you have to give same number of elements as the index of the dataframe is, however, its not the case with Series

# %%
# adding a column which shows the total fuel used for eac car
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             8.5
# 3     bmw  Black          11179      5  22000.0    5.0             6.7
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.5
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 8  toyota  White          60000      4   6250.0    5.0             3.5
# 9  nissan  White          31600      4   9700.0    5.0             5.2

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             8.5
# 3     bmw  Black          11179      5  22000.0    5.0             6.7
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.5
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 8  toyota  White          60000      4   6250.0    5.0             3.5
# 9  nissan  White          31600      4   9700.0    5.0             5.2
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         8086.708             8086.708
# 2         2766.665             2766.665
# ...

# %%
# create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             8.5
# 3     bmw  Black          11179      5  22000.0    5.0             6.7
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.5
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 8  toyota  White          60000      4   6250.0    5.0             3.5
# 9  nissan  White          31600      4   9700.0    5.0             5.2
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0        11253.225            11253.225                 4
# 1         8086.708             8086.708                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             8.5
# 3     bmw  Black          11179      5  22000.0    5.0             6.7
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.5
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 8  toyota  White          60000      4   6250.0    5.0             3.5
# 9  nissan  White          31600      4   9700.0    5.0             5.2
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed road safety
# 0        11253.225            11253.225                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                  float64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used        float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road safety        bool
# dtype: object

# %%
# drop the column "Total fuel used"
car_sales.drop("Total fuel used", axis = 1, inplace = True)
# (OR)
# car_sales = car_sales.drop("Total fuel used", axis = 1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             8.5
# 3     bmw  Black          11179      5  22000.0    5.0             6.7
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.5
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 8  toyota  White          60000      4   6250.0    5.0             3.5
# 9  nissan  White          31600      4   9700.0    5.0             5.2
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
# shuffing the order of 100% of data by giving parameter 'frac=1'
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3   7000.0    5.0             8.5
# 5  toyota  Green          99213      4   4500.0    5.0             6.5
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 4  nissan  White         213095      4   3500.0    5.0             5.0
# 8  toyota  White          60000      4   6250.0    5.0             3.5
# 9  nissan  White          31600      4   9700.0    5.0             5.2
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 3     bmw  Black          11179      5  22000.0    5.0             6.7
# 1   honda    Red          87899      4   5000.0    5.0             9.2
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 2             2766.665                 4                True
# 5             6448.845                 4                True
# ...

# %%
# only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#     Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 6  honda   Blue          45698      4   7500.0    5.0             5.3
# 3    bmw  Black          11179      5  22000.0    5.0             6.7
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 6             2421.994                 4                True
# 3              748.993                 4                True

# %%
# to sort the data
car_sales_shuffled.reset_index(drop = True,inplace = True)
# the drop parameter in reset_index() will drop the addition column of index created
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota   Blue          32549      3   7000.0    5.0             8.5
# 1  toyota  Green          99213      4   4500.0    5.0             6.5
# 2  toyota  White         150043      4   4000.0    5.0             7.5
# 3  nissan  White         213095      4   3500.0    5.0             5.0
# 4  toyota  White          60000      4   6250.0    5.0             3.5
# 5  nissan  White          31600      4   9700.0    5.0             5.2
# 6   honda   Blue          45698      4   7500.0    5.0             5.3
# 7   honda   Blue          54738      4   7000.0    5.0             2.3
# 8     bmw  Black          11179      5  22000.0    5.0             6.7
# 9   honda    Red          87899      4   5000.0    5.0             9.2
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0             2766.665                 4                True
# 1             6448.845                 4                True
# ...

# %%
# convert 'Odometer (KM)' to 'Odometer (Miles)'
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000.0    5.0             7.5
# 1   honda    Red      54936.875      4   5000.0    5.0             9.2
# 2  toyota   Blue      20343.125      3   7000.0    5.0             8.5
# 3     bmw  Black       6986.875      5  22000.0    5.0             6.7
# 4  nissan  White     133184.375      4   3500.0    5.0             5.0
# 5  toyota  Green      62008.125      4   4500.0    5.0             6.5
# 6   honda   Blue      28561.250      4   7500.0    5.0             5.3
# 7   honda   Blue      34211.250      4   7000.0    5.0             2.3
# 8  toyota  White      37500.000      4   6250.0    5.0             3.5
# 9  nissan  White      19750.000      4   9700.0    5.0             5.2
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car-sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-58c9c8f0a8c3> in <module>
# ----> 1 car-sales
#
# NameError: name 'car' is not defined
